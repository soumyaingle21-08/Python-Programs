# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyaingle21-08/Python-Programs/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = {0: 10, 1: 20}
d[2] = 30
print(d)
# Out:
# {0: 10, 1: 20, 2: 30}

# %%
dic1 = {1:10, 2:20}
dic2 = {3:30, 4:40}
dic3 = {5:50, 6:60}

result = {}
result.update(dic1)
result.update(dic2)
result.update(dic3)

print(result)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
d = {1:10, 2:20, 3:30}

key = int(input("Enter key: "))

if key in d:
    print("Key exists")
else:
    print("Key does not exist")
# Out:
# Enter key: 45
# Key does not exist

# %%
d = {1:10, 2:20, 3:30}

for key, value in d.items():
    print(key, value)
# Out:
# 1 10
# 2 20
# 3 30

# %%
n = int(input("Enter number: "))
d = {}

for x in range(1, n+1):
    d[x] = x*x

print(d)
# Out:
# Enter number: 3
# {1: 1, 2: 4, 3: 9}

# %%
d = {}

for i in range(1, 16):
    d[i] = i*i

print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
d1 = {1:10, 2:20}
d2 = {3:30, 4:40}

d1.update(d2)
print(d1)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40}

# %%
d = {"a":1, "b":2, "c":3}

for k in d:
    print(k, d[k])
# Out:
# a 1
# b 2
# c 3

# %%
d = {"a":100, "b":200, "c":300}

total = sum(d.values())

print(total)
# Out:
# 600

# %%
d = {"a":2, "b":3, "c":4}

result = 1
for v in d.values():
    result *= v

print(result)
# Out:
# 24

# %%
d = {1:10, 2:20, 3:30}

key = int(input("Enter key to remove: "))
d.pop(key, None)

print(d)
# Out:
# Enter key to remove: 20
# {1: 10, 2: 20, 3: 30}

# %%
keys = ['a', 'b', 'c']
values = [1, 2, 3]

d = dict(zip(keys, values))

print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d = {3:30, 1:10, 2:20}

sorted_dict = dict(sorted(d.items()))

print(sorted_dict)
# Out:
# {1: 10, 2: 20, 3: 30}

# %%
d = {"a":10, "b":50, "c":30}

print(max(d.values()))
print(min(d.values()))
# Out:
# 50
# 10

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s = Student("John", 20)

d = vars(s)

print(d)
# Out:
# {'name': 'John', 'age': 20}

# %%
d = {"a":100, "b":200, "c":100, "d":300}

temp = {}
for k, v in d.items():
    if v not in temp.values():
        temp[k] = v

print(temp)
# Out:
# {'a': 100, 'b': 200, 'd': 300}

# %%
d = {}

if not d:
    print("Dictionary is empty")
else:
    print("Dictionary is not empty")
# Out:
# Dictionary is empty

# %%
d1 = {'a':100, 'b':200, 'c':300}
d2 = {'a':300, 'b':200, 'd':400}

result = {}

for key in d1:
    if key in d2:
        result[key] = d1[key] + d2[key]
    else:
        result[key] = d1[key]

for key in d2:
    if key not in result:
        result[key] = d2[key]

print(result)
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}

# %%
d = {"V": "S001", "VI": "S002", "VII": "S001", "VIII": "S005",
     "IX": "S009", "X": "S007"}

unique_values = set(d.values())

print(unique_values)
# Out:
# {'S001', 'S007', 'S005', 'S009', 'S002'}

# %%
import itertools

data = {'1': ['a','b'], '2': ['c','d']}

result = list(itertools.product(*data.values()))

for i in result:
    print(''.join(i))
# Out:
# ac
# ad
# bc
# bd

# %%
d = {'a':10,'b':45,'c':23,'d':67,'e':12}

top3 = sorted(d.values(), reverse=True)[:3]

print("Highest 3 values:", top3)
# Out:
# Highest 3 values: [67, 45, 23]

# %%
from collections import Counter

data = [
{'item':'item1','amount':400},
{'item':'item2','amount':300},
{'item':'item1','amount':750}
]

result = Counter()

for d in data:
    result[d['item']] += d['amount']

print(result)
# Out:
# Counter({'item1': 1150, 'item2': 300})

# %%
string = "SSBIAIN"

d = {}

for ch in string:
    d[ch] = d.get(ch,0) + 1

print(d)
# Out:
# {'S': 2, 'B': 1, 'I': 2, 'A': 1, 'N': 1}

# %%
d = {'Name':'John','Age':25,'City':'London'}

print("Key\tValue")
print("-----------")

for k,v in d.items():
    print(k,"\t",v)
# Out:
# Key	Value
# -----------
# Name 	 John
# Age 	 25
# City 	 London

# %%
d = {
'a':[1,2,3,4,5,6],
'b':[7,8]
}

print(len(d['a']))
print(len(d['b']))
# Out:
# 6
# 2

# %%
lst = [1,2,3,4]

d = current = {}

for i in lst:
    current[i] = {}
    current = current[i]

print(d)
# Out:
# {1: {2: {3: {4: {}}}}}

# %%
d = {'letters':['b','e','a','d','c']}

d['letters'].sort()

print(d)
# Out:
# {'letters': ['a', 'b', 'c', 'd', 'e']}

# %%
d = {'a':'hello world','b':'python program'}

for k in d:
    d[k] = d[k].replace(" ","")

print(d)
# Out:
# {'a': 'helloworld', 'b': 'pythonprogram'}

# %%
data = {'item1':45.50,'item2':35,'item3':41.30,'item4':55,'item5':24}

top = sorted(data.items(), key=lambda x:x[1], reverse=True)[:3]

for item,price in top:
    print(item,price)
# Out:
# item4 55
# item1 45.5
# item3 41.3
