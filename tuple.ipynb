# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyaingle21-08/Python-Programs/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (10, "hello", 3.14)
print(t)
# Out:
# (10, 'hello', 3.14)

# %%
t = (1, 2, 3, 4, 5)
print(t[2])
# Out:
# 3

# %%
t1 = (1, 2, 3)
t2 = (4, 5, 6)

t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t = (10, 20, 30)

a, b, c = t
print(a, b, c)
# Out:
# 10 20 30

# %%
t = (1, 3, 5, 7, 9)

if 7 in t:
    print("Exists")
# Out:
# Exists

# %%
t = (0, 1, 2, 3, 4, 5)

print(t[2:5])
# Out:
# (2, 3, 4)

# %%
t = (10, 20, 30, 40, 50)

print(len(t))
# Out:
# 5

# %%
t = (1, 2, 3)

t2 = t * 3
print(t2)
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
l = [1, 2, 3]

t = tuple(l)
print(t)
# Out:
# (1, 2, 3)

# %%
t = (5, 12, 3, 8, 15)

print(min(t))
print(max(t))
# Out:
# 3
# 15

# %%
t = (1, 2, 3, 2, 4, 2)

print(t.count(2))
# Out:
# 3

# %%
t = (True, True, False)

print(all(t))
# Out:
# False

# %%
t = (1, 2, 3, 4, 3, 5)

print(t.index(3))
# Out:
# 2

# %%
t = (5, 2, 8, 1, 3)

sorted_t = tuple(sorted(t))
print(sorted_t)
# Out:
# (1, 2, 3, 5, 8)

# %%
t = tuple(i*i for i in range(1,6))

print(t)
# Out:
# (1, 4, 9, 16, 25)

# %%
t = (1, 2, 3, 4)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t = (10, "Python", 3.5, True)
print(t)
# Out:
# (10, 'Python', 3.5, True)

# %%
t = (5, 10, 15, 20)

print(t[1])
# Out:
# 10

# %%
t = (100, 200, 300)

x, y, z = t
print(x, y, z)
# Out:
# 100 200 300

# %%
t = (1, 2, 3)
t = t + (4,)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t = ('P', 'y', 't', 'h', 'o', 'n')

s = ''.join(t)
print(s)
# Out:
# Python

# %%
t = (10, 20, 30, 40, 50, 60)

print(t[-4])
# Out:
# 30

# %%
t = (1, 2, 3, 2, 4, 1)

repeat = set([x for x in t if t.count(x) > 1])
print(repeat)
# Out:
# {1, 2}

# %%
t = (10, 20, 30, 40)

if 20 in t:
    print("Exists")
# Out:
# Exists

# %%
l = [1, 2, 3, 4]

t = tuple(l)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t = (1, 2, 3, 4)

l = list(t)
l.remove(3)
t = tuple(l)

print(t)
# Out:
# (1, 2, 4)

# %%
t = (10, 20, 30, 40, 50)

print(t[1:4])
# Out:
# (20, 30, 40)

# %%
t = (5, 10, 15, 20)

print(t.index(15))
# Out:
# 2

# %%
t = (1, 2, 3, 4, 5)

print(len(t))
# Out:
# 5

# %%
t = (('a', 1), ('b', 2), ('c', 3))

d = dict(t)
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
t = [(1, 2), (3, 4), (5, 6)]

a, b = zip(*t)
print(a)
print(b)
# Out:
# (1, 3, 5)
# (2, 4, 6)

# %%
t = (1, 2, 3, 4)

rev = t[::-1]
print(rev)
# Out:
# (4, 3, 2, 1)

# %%
l = [('a', 1), ('b', 2), ('c', 3)]

d = dict(l)
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
l = [(), (), ('',), ('a','b'), ('a','b','c'), ('d')]

result = [i for i in l if i]
print(result)
# Out:
# [('',), ('a', 'b'), ('a', 'b', 'c'), 'd']

# %%
s = "python 3.0"

t = tuple(s)
print(t)
# Out:
# ('p', 'y', 't', 'h', 'o', 'n', ' ', '3', '.', '0')
