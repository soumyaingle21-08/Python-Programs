# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyaingle21-08/Python-Programs/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = [10, 20, 4, 45, 99]
largest = max(num)
print(largest)
# Out:
# 99

# %%
num = [10, 21, 33, 44, 55, 60]

for i in num:
    if i % 2 != 0:
        print(i)
# Out:
# 21
# 33
# 55

# %%
num = [1, 2, 3, 4, 5]

num.reverse()
print(num)
# Out:
# [5, 4, 3, 2, 1]

# %%
num = [1, 2, 3, 4, 5]

square = []
for i in num:
    square.append(i*i)

print(square)
# Out:
# [1, 4, 9, 16, 25]

# %%
num = ["Hello", 34, 45, "", 40]

num.remove("")
print(num)
# Out:
# ['Hello', 34, 45, 40]

# %%
num = [10, 15, 23, 40, 55, 62]

for i in num:
    if i % 5 == 0:
        print(i)
# Out:
# 10
# 15
# 40
# 55

# %%
num = [2,3,4,5,2,6,3,2]

result = list(set(num))
print(result)
# Out:
# [2, 3, 4, 5, 6]

# %%
list1 = [23, 24, 25, 26]
list2 = [27, 28, 29, 30]

list1.extend(list2)
print(list1)
# Out:
# [23, 24, 25, 26, 27, 28, 29, 30]

# %%
num = [2, 23, 24, 51, 46, 67]

even = []
odd = []

for i in num:
    if i % 2 == 0:
        even.append(i)
    else:
        odd.append(i)

print("Even:", even)
print("Odd:", odd)
# Out:
# Even: [2, 24, 46]
# Odd: [23, 51, 67]

# %%
num = [5, 2, 9, 1, 7]

num.sort()
print(num)
# Out:
# [1, 2, 5, 7, 9]

# %%
num = [10, 20, 30, 40, 50]

count = len(num)
print(count)
# Out:
# 5

# %%
chars = ['a', 'b', 'c', 'd', 'e']

rev = []
for i in range(len(chars)-1, -1, -1):
    rev.append(chars[i])

print(rev)
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

list1[2][2].append(7000)

print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
list1 = [5, 10, 15, 20, 25, 50, 20]

index = list1.index(20)
list1[index] = 200

print(list1)
# Out:
# [5, 10, 15, 200, 25, 50, 20]

# %%
num = [10, 5, 8, 20, 3]

largest = max(num)
smallest = min(num)

range_value = largest - smallest

print(range_value)
# Out:
# 17

# %%
num = [10, 20, 30, 40]

num.insert(2, 25)

print(num)
# Out:
# [10, 20, 25, 30, 40]

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]

common = []

for i in list1:
    if i in list2:
        common.append(i)

print(common)
# Out:
# [3, 4, 5]

# %%
num = [10, 5, 8, 3, 15]

num.sort()

print(num[1])
# Out:
# 5

# %%
num = [10, 20, 30, 40, 50, 60]

result = []

for i in range(len(num)):
    if i % 2 != 0:
        result.append(num[i])

print(result)
# Out:
# [20, 40, 60]

# %%
num = [10, 20, 30, 40, 50]

sum = 0

for i in range(len(num)):
    if i % 2 != 0:
        sum = sum + num[i]

print(sum)
# Out:
# 60
